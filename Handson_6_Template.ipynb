# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
def main():
    print("Country\t\tWins\tYears\n=======\t\t====\t=====")
    cups = dict()
    with open("world_cup_champions.txt") as f:
        champions = f.readlines()
        for line in champions:
            x = line.split(",")
            if x[1] in cups:
                yr = cups[x[1]]
                cups[x[1]] = yr.append(x[0])
            else:
                cups[x[1]] = [x[0]]
    for country, years in cups.items():
        wins = ", ".join(years)
        print(country + "\t\t" + str(len(years)) + "\t" + wins)

if __name__ == "__main__":
    main()
# Out:
# Country		Wins	Years
# =======		====	=====
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 18
#      15         print(country + "\t\t" + str(len(years)) + "\t" + wins)
#      17 if __name__ == "__main__":
# ---> 18     main()
#
# Cell In[7], line 10, in main()
#       8 if x[1] in cups:
#       9     yr = cups[x[1]]
# ---> 10     cups[x[1]] = yr.append(x[0])
#      11 else:
#      12     cups[x[1]] = [x[0]]
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
sales = dict()
with open("monthly_sales.txt") as f:
    monthly_sales = f.readlines()
    for line in monthly_sales:
        x = line.split("\t")
        sales[x[0]] = x[1]

cont = "y"

def get_command(x):
    if x == "view":
        view()
    elif x == "edit":
        edit()
    elif x == "totals":
        totals()
    elif x == "exit":
        global cont
        cont = "n"
    else:
        print("Invalid input.  Please try again.")
        get_command(input("Command: "))

def view():
    global sales
    month = input("Three-letter Month: ")
    month = month.capitalize()
    if month in sales:
        print("Sales amount for " + month + " is " + str(round(float(sales[month]),2)) + ".")
    else:
        print("Error, please try again")

def edit():
    global sales
    month = input("Three-letter Month: ")
    month = month.capitalize()
    if month in sales:
        amount = input("Sales Amount: ")
        sales[month] = amount
        print("Sales amount for " + month + " is " + str(round(float(sales[month]),2)) + ".")
    else:
        print("Error, please try again")

def totals():
    global sales
    total = 0
    average = 0
    for month in sales:
        total = total+float(sales[month])
    average = total/12
    print("Yearly total: " + str(round(total,2)) + "\nMonthly average: " + str(round(average,2)))
        

def main():
    print("Monthly Sales program\nCOMMAND MENU\nview\t- View sales for specified month\nedit\t- Edit sales for specified month\ntotals\t- View sales summary for year\nexit\t- Exit program")
    global cont
    print()
    while cont == "y":
        print()
        get_command(input("Command: "))
    print("Bye!")

if __name__ == "__main__":
    main()
# Out:
# Monthly Sales program
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals	- View sales summary for year
# exit	- Exit program
# Command:  view
# Three-letter Month:  jan
# Sales amount for Jan is 14317.0.
# Command:  edit
# Three-letter Month:  jan
# Sales Amount:  15293
# Sales amount for Jan is 15293.0.
# Command:  totals
# Yearly total: 67855.0
# Monthly average: 5654.58
# Command:  view
# Three-letter Month:  july
# Error, please try again
# Command:  exit
# Bye!
